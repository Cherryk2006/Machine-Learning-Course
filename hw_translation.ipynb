# %%
# !pip install transformers sentencepiece torch
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
# !pip install sacremoses
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 1.3 MB/s  0:00:0036m-:--:--
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
model_name = "Helsinki-NLP/opus-mt-en-uk"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# Loading weights: 100%|██████████| 258/258 [00:00<00:00, 35332.56it/s]

# %%
text = "My name Anastasiia"
print("Original text:")
print(text)
# Out:
# Original text:
# My name Anastasiia

# %%
inputs = tokenizer(text, return_tensors="pt")

translated_tokens = model.generate(
    **inputs,
    max_length=100
)

translated_text = tokenizer.decode(
    translated_tokens[0],
    skip_special_tokens=True
)

print("Translation:")
print(translated_text)
# Out:
# Translation:
# Моє ім'я Анастасія

# %%
def translate_text(text):
    inputs = tokenizer(text, return_tensors="pt")   
    translated_tokens = model.generate(
        **inputs,
        max_length=100
    )
    
    translation = tokenizer.decode(
        translated_tokens[0],
        skip_special_tokens=True
    )
    return translation

# %%
sentence = "I am a girl."
result = translate_text(sentence)
print("English:", sentence)
print("Ukrainian:", result)
# Out:
# English: I am a girl.
# Ukrainian: Я дівчинка.

# %%
user_text = input("Enter English text: ")
translation = translate_text(user_text)
print("\nTranslation:")
print(translation)
# Out:
# Translation:
# Привіт.
